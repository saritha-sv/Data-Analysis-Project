# %% [markdown]
# <font color="Red" align ="centre"><h1><b>Project Title : Bank Dataset Analysis</b> </h1></font><br/>
# <h3><b>Purpose :</b></h3><p>Analyzing a bank dataset using Pandas and Matplotlib serves multiple purposes aimed at optimizing operations and enhancing customer experiences. Through Pandas, the dataset's rich information on customer demographics, financial activities, and interactions can be meticulously explored. Matplotlib, in turn, facilitates the visualization of these insights, making complex data more comprehensible and actionable. This analysis enables segmentation of customers based on various criteria such as age, job, and marital status, allowing tailored strategies for marketing, risk assessment, and customer relationship management. Moreover, trends in financial performance, including deposit behavior and loan default rates, can be identified and monitored over time. By harnessing these tools collaboratively, banks can make informed decisions, refine marketing strategies, mitigate risks, and ultimately foster stronger customer relationships while improving overall operational efficiency.</p>

# %% [markdown]
# <h3><b>Step 1: import necessary libraries for Data Visualization and Data Manipulation</b></h3>

# %%
import pandas as pd # used for data representation
import matplotlib as mpl # used for show data interms of graphs

# %% [markdown]
# <font size = 6px><b>Step 2: loading the data set from local to pandas to create seperate data set</b></font>

# %%
# it reads the dataset from local
data = pd.read_csv('bank.csv', encoding='latin1') 
data
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# <font size = 5px><b>Data.shape</b></font>

# %%
# it shows number of rows and colums present in the dataset
data.shape 
print("rows =",data.shape[0])
print("Columns =",data.shape[1])
# Out:
# rows = 11162
# Columns = 17

# %% [markdown]
# <font size =6px><b>Step 3: Data Cleaning/Data Filtering / Manipulation</b></font>

# %%
# it shows all the colums present in the dataset.
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# <font size =5px><b>DataFrame</b></font>

# %%
# This shows the DataFrame of the dataset
data = pd.DataFrame(data)
print(data)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# <font size =5px><b>Data info</b></font>

# %%
# it describes the information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# <font size =5px><b>Data head</b></font>

# %%
# it shows the top 5 rows by default head()
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# <font size =5px><b>Data tail</b></font>

# %%
#it displays bottom 5 rows by default tail()
data.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %% [markdown]
# <font size =5px><b>Data describe</b></font>

# %%
# describes the data in the dataset
data.describe
# Out:
# <bound method NDFrame.describe of        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
# ...

# %% [markdown]
# <font size =5px><b>Data count</b></font>

# %%
# it gives the total count of data present in the dataset
data.count()
# Out:
# age          11162
# job          11162
# marital      11162
# education    11162
# default      11162
# balance      11162
# housing      11162
# loan         11162
# contact      11162
# day          11162
# month        11162
# duration     11162
# campaign     11162
# pdays        11162
# previous     11162
# poutcome     11162
# deposit      11162
# dtype: int64

# %% [markdown]
# <font size =5px><b>Data value counts</b></font>

# %%
# it counts the data values in the dataset
data.value_counts
# Out:
# <bound method DataFrame.value_counts of        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
# ...

# %% [markdown]
# <font size=5px><b>data.unique()</b></font>

# %%
# gives the unique values present in specified column
data['day'].unique()
# Out:
# array([ 5,  6,  7,  8,  9, 12, 13, 14, 15, 16, 19, 20, 21, 23, 26, 27, 28,
#        29, 30,  2,  3,  4, 11, 17, 18, 24,  1, 10, 22, 25, 31],
#       dtype=int64)

# %% [markdown]
# <font size=5px><b>Data.dropna</b></font>

# %%
#used to remove null values from the dataset
data.dropna
# Out:
# <bound method DataFrame.dropna of        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
# ...

# %%
# checking the rows and cloumns after droping null vaues
data.shape
# Out:
# (11162, 17)

# %%
# checks the rows and if any null value found replaces with True
data.dropna(inplace=True)

# %%
# checks the duplicate values in the specified column
data['contact'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 11157     True
# 11158     True
# 11159     True
# 11160     True
# 11161     True
# Name: contact, Length: 11162, dtype: bool

# %%
# if duplicates found it removes the duplicate record from the dataset
data.drop_duplicates(inplace=True)

# %%
# the sum() will give the overall count of the duplicate values present in Dataset
duplicate_rows = data.duplicated()
print(duplicate_rows.sum())
# Out:
# 0

# %% [markdown]
# <font size=6px><b> Step: 4 Data Sorting / Searching / Validation </b>

# %%
data['balance'] # dispalys balance value in shuffled manner
# Out:
# 0        2343
# 1          45
# 2        1270
# 3        2476
# 4         184
#          ...
# 11157       1
# 11158     733
# 11159      29
# 11160       0
# 11161       0
# Name: balance, Length: 11162, dtype: int64

# %%
# arranging profit value in ascending order
data.sort_values('balance', ascending=True)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 6797    49     management   married   tertiary     yes    -6847      no  yes
# 1525    39  self-employed   married   tertiary      no    -3058     yes  yes
# 10642   52     management   married   tertiary      no    -2712     yes  yes
# 6388    51     management  divorced   tertiary      no    -2282     yes  yes
# 6010    49     management  divorced   tertiary      no    -2049     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 3236    61  self-employed  divorced   tertiary      no    52587      no   no
# 10143   43         admin.    single  secondary      no    56831      no   no
# 8208    52    blue-collar   married    primary      no    66653      no   no
# 3043    84        retired   married  secondary      no    81204      no   no
# 3380    84        retired   married  secondary      no    81204      no   no
#
# ...

# %%
# arranging Sales values in descending order
data.sort_values('balance', ascending= False)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 3380    84        retired   married  secondary      no    81204      no   no
# 3043    84        retired   married  secondary      no    81204      no   no
# 8208    52    blue-collar   married    primary      no    66653      no   no
# 10143   43         admin.    single  secondary      no    56831      no   no
# 2468    61  self-employed  divorced   tertiary      no    52587      no   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 6010    49     management  divorced   tertiary      no    -2049     yes   no
# 6388    51     management  divorced   tertiary      no    -2282     yes  yes
# 10642   52     management   married   tertiary      no    -2712     yes  yes
# 1525    39  self-employed   married   tertiary      no    -3058     yes  yes
# 6797    49     management   married   tertiary     yes    -6847      no  yes
#
# ...

# %%
# displays the balance values which are above 800
balance_above_800 = data[data['balance']>800]['balance']
print("         v")
print(balance_above_800)
# Out:
#          v
# 0        2343
# 2        1270
# 3        2476
# 6         830
# 9        5090
#          ...
# 11134    2596
# 11139    2593
# 11140    2166
# 11149    3317
# 11151     917
# Name: balance, Length: 4640, dtype: int64

# %% [markdown]
# <font size = 6px><b>Step: 5 Data Visualization </b></font>

# %%
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# <font size = 5px><b>Bar Graph</b></font>

# %%
# Assuming 'data' is your DataFrame
grouped = data.groupby('job')['balance'].mean()
grouped.plot(kind='bar')
plt.title('Mean Balance by Job')
plt.xlabel('Job')
plt.ylabel('Mean Balance')
plt.show()

# %% [markdown]
# <font size = 5px><b>Horzontal Bar Graph</b></font>

# %%
# Assuming 'data' is your DataFrame
grouped = data.head(20).groupby('marital')['balance']
grouped.plot(kind='barh')
plt.title('Distribution of Balance by Marital Status')
plt.ylabel('Balance')
plt.xlabel('Marital Status')
plt.show()

# %% [markdown]
# <h5><b>Pie Chart</b></h5>

# %%
# Assuming 'data' is your DataFrame
grouped = data.groupby('education').size()

# Plotting the pie chart
grouped.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Education Levels')
plt.ylabel('')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# <h3><b>Histogram Graph</b></h3>

# %%
# Assuming 'data' is your DataFrame
grouped = data.groupby('education')['balance']
grouped.plot(kind='hist', alpha=0.5, bins=20)
plt.title('Distribution of Balance by Education')
plt.xlabel('Balance')
plt.ylabel('Frequency')
plt.legend(title='Education')
plt.show()

# %% [markdown]
# <font size = 5px><b>line chart</b></font>

# %%
# Assuming 'data' is your DataFrame
grouped = data.groupby('month')['duration'].mean()
grouped.plot(kind='line', marker='o')
plt.title('Mean Duration by Month')
plt.xlabel('Month')
plt.ylabel('Mean Duration')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <font size = 5px><b>Scatter Graph</b></font>

# %%
# Assuming 'data' is your DataFrame
grouped = data.groupby('campaign')
for name, group in grouped:
    plt.scatter(group['duration'], group['balance'], label=name, alpha=0.5)
plt.title('Duration vs Balance by Campaign')
plt.xlabel('Duration')
plt.ylabel('Balance')
plt.legend(title='Campaign')
plt.show()

# %% [markdown]
# <font size = 6px><b>Step 6: Aggregate Functions</b></font>

# %%
# groupby function for Customer ID and Quantity
df = pd.DataFrame(data)
grouped=df.groupby('job')['contact'].count()
print(grouped)
# Out:
# job
# admin.           1334
# blue-collar      1944
# entrepreneur      328
# housemaid         274
# management       2566
# retired           778
# self-employed     405
# services          923
# student           360
# technician       1823
# unemployed        357
# unknown            70
# Name: contact, dtype: int64

# %%
# Assuming data is your DataFrame
aggregate_functions = {
    'balance': ['sum', 'mean', 'median', 'min', 'max', 'std', 'count'],    
}
summary_statistics = data.agg(aggregate_functions)
print(summary_statistics)
# Out:
#              balance
# sum     1.706155e+07
# mean    1.528539e+03
# median  5.500000e+02
# min    -6.847000e+03
# max     8.120400e+04
# std     3.225413e+03
# count   1.116200e+04

# %% [markdown]
# <font size = 6px><b>CONCLUSION</b></font><br/>
# In the bank dataset project, conducted through the lens of Pandas and Matplotlib, a comprehensive exploration of the bank's operations and customer interactions was undertaken. Leveraging Pandas' robust data manipulation capabilities, the dataset was meticulously analyzed, revealing intricate patterns and trends within the data. Through the aggregation and grouping functions of Pandas, key insights emerged, such as customer segmentation based on demographic factors like age, job, and marital status. These insights proved invaluable in tailoring marketing strategies, risk assessment, and customer relationship management approaches. Matplotlib complemented the analysis by providing clear visualizations of the data, aiding in the interpretation and communication of findings. From evaluating marketing campaign effectiveness to assessing financial performance and risk exposure, the project showcased the transformative potential of data analytics in informing strategic decision-making within the banking sector. Ultimately, the seamless integration of Pandas and Matplotlib facilitated a deeper understanding of the dataset, empowering stakeholders to make data-driven decisions that drive operational efficiency and enhance customer satisfaction.
